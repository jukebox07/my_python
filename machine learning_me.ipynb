# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
# Load library
from nltk.tokenize import word_tokenize
# Create text
string = "The science of today is the technology of tomorrow"
# Tokenize words
word_tokenize(string)
# Out:
# ['The', 'science', 'of', 'today', 'is', 'the', 'technology', 'of', 'tomorrow']

# %%
import cv2
cv2.__version__
# Out:
# '4.5.5'

# %%
from matplotlib import pyplot as plt
image=cv2.imread('C:\\Users\\User\\Pictures\\mourinho.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(image, cmap="gray")
plt.axis("off")
# Out:
# (-0.5, 799.5, 449.5, -0.5)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image
# Out:
# array([[180, 180, 179, ..., 139, 139, 139],
#        [180, 180, 179, ..., 139, 139, 139],
#        [181, 180, 180, ..., 139, 139, 139],
#        ...,
#        [171, 171, 173, ...,  90,  90,  91],
#        [175, 174, 174, ...,  84,  84,  84],
#        [175, 174, 174, ...,  84,  84,  84]], dtype=uint8)

# %%
image.shape
# Out:
# (450, 800)

# %%
image[0,0]
# Out:
# 180

# %%
image_bgr = cv2.imread("C:\\Users\\User\\Pictures\\mourinho.jpg", cv2.IMREAD_COLOR)
# Show pixel
image_bgr[0,0]
# Out:
# array([187, 180, 177], dtype=uint8)

# %%
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
# Show image
plt.imshow(image_rgb)
plt.axis("off");

# %%
# Saving Images
# Problem: You want to save an image for preprocessing.
# Solution: Use OpenCV’s imwrite:

# Load image as grayscale
image = cv2.imread("C:\\Users\\User\\Pictures\\mourinho.jpg", cv2.IMREAD_GRAYSCALE)
# Save image
cv2.imwrite("Documents\Mourinho.jpg", image)
# Out:
# True

# %%
import numpy as np

# %%
image_bgr = cv2.imread("C:\\Users\\User\\Documents\\Mourinho.jpg")
image_gray = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)
# Number of corners to detect
corners_to_detect = 10
minimum_quality_score = 0.05
minimum_distance = 25
# Detect corners
corners = cv2.goodFeaturesToTrack(image_gray, corners_to_detect, minimum_quality_score, 
                                  minimum_distance)
corners = np.int32(corners)
# Draw white circle at each corner
for corner in corners:
    x, y = corner[0]
    cv2.circle(image_bgr, (x,y), 20, (255,255,255), -1)
# Convert to grayscale
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)
# Show image
plt.imshow(image_rgb, cmap='gray'), plt.axis("off");
